# %% [markdown]
# <a href="https://colab.research.google.com/github/tanpharamut/data_viz/blob/main/Pandas_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os 
path = '/content/drive/My Drive/data_viz'

# %%
covid_file_path = os. path.join(path,'pm-20-jan-2021.csv')
print(covid_file_path)
# Out:
# /content/drive/My Drive/data_viz/pm-20-jan-2021.csv

# %%
a = path + '/pm-20-jan-2021.csv'
print(a)
# Out:
# /content/drive/My Drive/data_viz/pm-20-jan-2021.csv

# %% [markdown]
# ##load data to memory

# %%
data_covid = pd.read_csv(covid_file_path)
data_covid
# Out:
#          No.  ...                                         risk
# 0          1  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          2  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          3  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 3          4  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# 4          5  ...             คนต่างชาติเดินทางมาจากต่างประเทศ
# ...      ...  ...                                          ...
# 12648  12649  ...                             State Quarantine
# 12649  12650  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12650  12651  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651  12652  ...                                Cluster ระยอง
# 12652  12653  ...  สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [12653 rows x 10 columns]

# %% [markdown]
# ##แบบง่าย เเต่ใช้การไม่ค่อยได้(มองแบบ array เเล้วตัดแบบ array)

# %%
data_covid.iloc[1:5,:]
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [4 rows x 10 columns]

# %% [markdown]
# ##แบบ advanced เเต่ใช้ประโยชน์ได้เยอะกว่า (ตัดแบบใช้ logic qucy)

# %%
data_covid[data_covid['province_of_onset']=='ขอนแก่น']
# Out:
#          No.  ...                                           risk
# 180      181  ...                                        สนามมวย
# 462      463  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 1466    1467  ...                  คนไทยเดินทางกลับจากต่างประเทศ
# 1970    1971  ...  ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# 2637    2638  ...                  สัมผัสผู้เดินทางจากต่างประเทศ
# 2673    2674  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 5948    5949  ...                              Cluster สมุทรสาคร
# 6082    6083  ...                              Cluster สมุทรสาคร
# 9333    9334  ...                           อยู่ระหว่างการสอบสวน
# 9334    9335  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 10610  10611  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11517  11518  ...                           อยู่ระหว่างการสอบสวน
# 11697  11698  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 11698  11699  ...    สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [14 rows x 10 columns]

# %% [markdown]
# ### data_covid[x] x สามารถมีค่าที่ใส่เข้าไปได้ 2 แบบ
#
# 1. ชื่อ column
# 2. ใส่ rows ที่ต้องการ (ใส่ list ที่มีขนาดเท่ากับจำนวนเเถว เเล้วบอกว่าเอา แถวไหนบ้างโดย ใช้ logical expression (```True```/```False```)

# %%
eight_rows_covid = data_covid.iloc[:8,:]
eight_rows_covid
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5    6     1/25/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 6    7     1/26/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 7    8     1/26/2020  ...            หัวหิน  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [8 rows x 10 columns]

# %%
eight_rows_covid[[True,False,True,True,False,True,False,False]]
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2    3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5    6     1/25/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [4 rows x 10 columns]

# %%
eight_rows_covid['province_of_onset'] == 'กรุงเทพมหานคร'
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# 5     True
# 6     True
# 7    False
# Name: province_of_onset, dtype: bool

# %%
eight_rows_covid[eight_rows_covid['province_of_onset'] == 'กรุงเทพมหานคร']
# Out:
#    No. announce_date  ... district_of_onset                              risk
# 0    1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1    2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3    4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4    5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 5    6     1/25/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 6    7     1/26/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [6 rows x 10 columns]

# %% [markdown]
# in class หาจำนวนผู้ป่วยที่เป็น คนช่างชาติเดินทางมาจากต่างประเทศ

# %%
data_covid[data_covid['risk']=='คนต่างชาติเดินทางมาจากต่างประเทศ']
# Out:
#          No. announce_date  ... district_of_onset                              risk
# 0          1     1/12/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 1          2     1/17/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 2          3     1/22/2020  ...             เมือง  คนต่างชาติเดินทางมาจากต่างประเทศ
# 3          4     1/22/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# 4          5     1/24/2020  ...               NaN  คนต่างชาติเดินทางมาจากต่างประเทศ
# ...      ...           ...  ...               ...                               ...
# 9852    9853      1/9/2021  ...            แม่สอด  คนต่างชาติเดินทางมาจากต่างประเทศ
# 10341  10342     1/11/2021  ...            แม่สอด  คนต่างชาติเดินทางมาจากต่างประเทศ
# 10616  10617     1/12/2021  ...          ปทุุมวัน  คนต่างชาติเดินทางมาจากต่างประเทศ
# 10619  10620     1/12/2021  ...            บางรัก  คนต่างชาติเดินทางมาจากต่างประเทศ
# 10620  10621     1/12/2021  ...             วัฒนา  คนต่างชาติเดินทางมาจากต่างประเทศ
#
# [155 rows x 10 columns]

# %%
data_covid[data_covid['risk']=='คนต่างชาติเดินทางมาจากต่างประเทศ'].shape[0]
# Out:
# 155

# %% [markdown]
# #HW (ให้ใช้เฉพาะที่อาจารย์สอนไปเเล้วในวิชานี้)
# #1. คำนวณอายุเฉลยของผู้หญิง เเละผู้ชายของข้อมูลทั้งหมด
# #2. คำนวณของผู้หญิง เเละผู้ชายของผู้ป่วยในจังหวัดขอนแก่น

# %%
avg_all = data_covid[['sex','age']]

# %%
avg_all_w = avg_all[avg_all['sex'] == 'หญิง']
avg_all_w_age = avg_all_w[['age']]
avg_all_w_age_dp = avg_all_w_age.dropna()
avg_all_w_age_dp_v = avg_all_w_age_dp.values

# %%
avg_all_m = avg_all[avg_all['sex'] == 'ชาย']
avg_all_m_age = avg_all_m[['age']]
avg_all_m_age_dp = avg_all_m_age.dropna()
avg_all_m_age_dp_v = avg_all_m_age_dp.values

# %%
answerforwo_all = []
for i in avg_all_w_age_dp_v :
      data = float(i)
      answerforwo_all.append(data)

# %%
answerform_all = []
for i in avg_all_m_age_dp_v :
      data = float(i)
      answerform_all.append(data)

# %%
def my_mean(sample):
    return sum(sample) / len(sample)

# %%
ans1_1 = my_mean(answerforwo_all)
ans1_2 = my_mean(answerform_all)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-83-c3b7edd62111> in <module>()
# ----> 1 ans1_1 = my_mean(answerforwo_all)
#       2 ans1_2 = my_mean(answerform_all)
#
# <ipython-input-82-354f14c0a8dd> in my_mean(sample)
#       1 def my_mean(sample):
# ----> 2     return sum(sample) / len(sample)
#
# TypeError: 'float' object is not callable

# %%
print(f'ค่าอายุเฉลี่ยของเพศหญิงทั่วประเทศที่ติดโควิด19 เท่ากับ {ans1_1}')
print(f'ค่าอายุเฉลี่ยของเพศชายทั่วประเทศที่ติดโควิด19 เท่ากับ {ans1_2}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-d6d068aefad5> in <module>()
# ----> 1 print(f'ค่าอายุเฉลี่ยของเพศหญิงทั่วประเทศที่ติดโควิด19 เท่ากับ {ans1_1}')
#       2 print(f'ค่าอายุเฉลี่ยของเพศชายทั่วประเทศที่ติดโควิด19 เท่ากับ {ans1_2}')
#
# NameError: name 'ans1_1' is not defined

# %% [markdown]
# ###2.คำนวณ อายุเฉลี่ยของผู้ป่วยในจังหวัดขอนแก่น

# %%
avg_KK = data_covid[['sex','age']]

# %%
avg_KK_w = avg_KK[avg_KK['sex'] == 'หญิง']
avg_KK_w_age = avg_KK_w[['age']]
avg_KK_w_v = avg_KK_w_age.values

# %%
avg_KK_m = avg_KK[avg_KK['sex'] == 'ชาย']
avg_KK_m_age = avg_KK_m[['age']]
avg_KK_m_v = avg_KK_m_age.values

# %%
answerfor_wo = []
for i in avg_KK_w_v:
      data = float(i)
      answerfor_wo.append(data)

# %%
answerfor_men = []
for i in avg_KK_m_v:
      data = float(i)
      answerfor_men.append(data)

# %%
ans2_1 = my_mean(answerfor_wo)
ans2_2 = my_mean(answerfor_men)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-0ecdf8127230> in <module>()
# ----> 1 ans2_1 = my_mean(answerfor_wo)
#       2 ans2_2 = my_mean(answerfor_men)
#
# <ipython-input-34-354f14c0a8dd> in my_mean(sample)
#       1 def my_mean(sample):
# ----> 2     return sum(sample) / len(sample)
#
# TypeError: 'float' object is not callable

# %%
print(f'ค่าอายุเฉลี่ยของเพศหญิงจังหวัดขอนแก่นที่ติดโควิด19 เท่ากับ {ans2_1}')
print(f'ค่าอายุเฉลี่ยของเพศชายจังหวัดขอนแก่นที่ติดโควิด19 เท่ากับ {ans2_2}')

# %% [markdown]
# ### 28/1/2021 8:56 น.

# %% [markdown]
# ###เฉลยการบ้าน

# %%
this_data = avg_all[avg_all['sex'] == 'หญิง']
female_all = this_data['age']

# %%
N = 0
for a in female_all:
    if a > 0:
       sum += a # sum = sum + a
       N += 1
print(f'ค่าอายุเฉลี่ยของเพศหญิงทั่วประเทศที่ติดโควิด19 เท่ากับ{sum/N}')
# Out:
# ค่าอายุเฉลี่ยของเพศหญิงทั่วประเทศที่ติดโควิด19 เท่ากับ36.63955450022614

# %%
female_KK = avg_KK_w['age']

# %%
sum = 0
N = 0
for a in female_KK:
    if a > 0:
       sum += a # sum = sum + a
       N += 1
print(f'ค่าอายุเฉลี่ยของเพศหญิงจังหวัดขอนแก่นที่ติดโควิด19 เท่ากับ{sum/N}')
# Out:
# ค่าอายุเฉลี่ยของเพศหญิงจังหวัดขอนแก่นที่ติดโควิด19 เท่ากับ36.63955450022614

# %% [markdown]
# การจัดการ Missing Value
# 1. ลบ record ที่เป็น missing
# 2. แทนที่ ค่า missing ด้วยค่าที่เหมาะสม mean, default
# 3. ใช้ค่าจาก column อื่นช่วยประมาณค่าใน columnที่หายไป (regression, deep learning, etc.)
# ลบ record (dropna)
# missing = None NA(not autorized) NaN (not )

# %%
this_data = data_covid[['sex','age','province_of_onset']]

# %%
this_data.shape
# Out:
# (12653, 3)

# %%
print(data_covid.shape)
print(data_covid.dropna().shape)
# Out:
# (12653, 10)
# (6655, 10)

# %%
this_data.dropna().shape
# Out:
# (8478, 3)

# %%
this_data.dropna()
print(this_data.shape)
# Out:
# (12653, 3)

# %%
this_data.dropna(inplace=True) #inplace คือการให้อัปเดตตารางหรือไม่ True คืออัปเดตเลย
print(this_data.shape)
# Out:
# (8478, 3)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
this_data = data_covid[['sex','age','province_of_onset']]
this_data.shape
# Out:
# (12653, 3)

# %%
this_data.dropna(subset=['age']).shape #subset คือการเลือกดูเฉพาะ column
# Out:
# (8881, 3)

# %% [markdown]
# ###แทน missing ด้วยค่าที่เหมาะสม(fillna)

# %%
this_data.head()
# Out:
#     sex   age province_of_onset
# 0  หญิง  61.0     กรุงเทพมหานคร
# 1  หญิง  74.0     กรุงเทพมหานคร
# 2  หญิง  73.0            นครปฐม
# 3   ชาย  68.0     กรุงเทพมหานคร
# 4  หญิง  66.0     กรุงเทพมหานคร

# %%
print(f'จำนวน record ก่อน drop missing ใน province {this_data.shape[0]}')
print(f"จำนวน record หลัง drop missing ใน province {this_data.dropna(subset=['province_of_onset']).shape[0]}")
# Out:
# จำนวน record ก่อน drop missing ใน province 12653
# จำนวน record หลัง drop missing ใน province 10662

# %%
this_data_updated = this_data.fillna(value={'sex':'ไม่รู้' , 'age':-1,'province_of_onset':'ไม่รู้'})
this_data_updated.head()
# Out:
#     sex   age province_of_onset
# 0  หญิง  61.0     กรุงเทพมหานคร
# 1  หญิง  74.0     กรุงเทพมหานคร
# 2  หญิง  73.0            นครปฐม
# 3   ชาย  68.0     กรุงเทพมหานคร
# 4  หญิง  66.0     กรุงเทพมหานคร

# %%
this_data_updated[this_data_updated['sex']=='ไม่รู้']
# Out:
#           sex  age province_of_onset
# 4391   ไม่รู้ -1.0         สมุทรสาคร
# 4392   ไม่รู้ -1.0         สมุทรสาคร
# 4393   ไม่รู้ -1.0         สมุทรสาคร
# 4394   ไม่รู้ -1.0         สมุทรสาคร
# 4395   ไม่รู้ -1.0         สมุทรสาคร
# ...       ...  ...               ...
# 12635  ไม่รู้ -1.0         สมุทรสาคร
# 12636  ไม่รู้ -1.0         สมุทรสาคร
# 12637  ไม่รู้ -1.0         สมุทรสาคร
# 12638  ไม่รู้ -1.0         สมุทรสาคร
# 12639  ไม่รู้ -1.0         สมุทรสาคร
#
# [2502 rows x 3 columns]

# %%
this_data_updated2 = this_data.fillna(value={'province_of_onset':'ไม่รู้'})

# %%
this_data_updated2[this_data_updated2['province_of_onset']=='ไม่รู้']
# Out:
#         sex   age province_of_onset
# 414     ชาย  29.0            ไม่รู้
# 529     ชาย  37.0            ไม่รู้
# 555    หญิง   6.0            ไม่รู้
# 576     ชาย   NaN            ไม่รู้
# 588     ชาย   NaN            ไม่รู้
# ...     ...   ...               ...
# 12405   NaN   NaN            ไม่รู้
# 12406   NaN   NaN            ไม่รู้
# 12407   NaN   NaN            ไม่รู้
# 12408   NaN   NaN            ไม่รู้
# 12409   NaN   NaN            ไม่รู้
#
# [1991 rows x 3 columns]

# %% [markdown]
# ###การวนลูป record ในตาราง (iterrows)

# %%
for each_row in this_data.iterrows():
    #print(each_row)
    #print(each_row[1])
    if each_row[1]['age'] == 20 and (each_row[1]['province_of_onset']=='ขอนแก่น'):
       print(each_row)
# Out:
# (9334, sex                      ชาย
# age                       20
# province_of_onset    ขอนแก่น
# Name: 9334, dtype: object)

# %% [markdown]
# ### การวนลูป แบบมองตารางเเพนด้าส์(pandas dataframe) เป็น numpy array (.iloc)

# %%
for each_row in range(this_data.shape[0]):
      if (this_data.iloc[each_row,1] == 20) and (this_data.iloc[each_row,2] == 'ขอนแก่น') :
          print(each_row)
          print(this_data.iloc[each_row,:])                       #each_row คือ ตัวเลข
# Out:
# 9334
# sex                      ชาย
# age                       20
# province_of_onset    ขอนแก่น
# Name: 9334, dtype: object

# %% [markdown]
# ### Quiz ตัดตารางออกมาเฉพาะปี 2021 ```announce_date``` ในปี 2021
# Hint
# + วนลูปหา index ของปี 2021
# + ตัดตารางมาเฉพาะปี 2021

# %%
for each_row in data_covid.iterrows():
    if (each_row[1]['announce_date'] == '1/1/2021'):
        print(each_row)
# Out:
# (6884, No.                                   6885
# announce_date                     1/1/2021
# notification_date               12/31/2020
# sex                                   หญิง
# age                                     40
# nationality                       Thailand
# province_of_isolation        กรุงเทพมหานคร
# province_of_onset                 ปทุมธานี
# district_of_onset                 คลองหลวง
# risk                     Cluster สมุทรสาคร
# Name: 6884, dtype: object)
# (6885, No.                               6886
# announce_date                 1/1/2021
# notification_date           12/31/2020
# sex                               หญิง
# age                                 21
# nationality                   Thailand
# province_of_isolation         ปทุมธานี
# province_of_onset             ปทุมธานี
# district_of_onset             คลองหลวง
# risk                     Cluster ระยอง
# Name: 6885, dtype: object)
# (6886, No.                             6887
# announce_date               1/1/2021
# notification_date         12/31/2020
# sex                             หญิง
# age                               20
# nationality                 Thailand
# province_of_isolation         นครปฐม
# province_of_onset             นครปฐม
# district_of_onset            สามพราน
# risk                     สถานบันเทิง
# Name: 6886, dtype: object)
# (6887, No.                                   6888
# announce_date                     1/1/2021
# notification_date               12/31/2020
# sex                                   หญิง
# age                                     47
# nationality                       Thailand
# province_of_isolation            สมุทรสาคร
# province_of_onset                   นครปฐม
# district_of_onset                  สามพราน
# risk                     Cluster สมุทรสาคร
# Name: 6887, dtype: object)
# (6888, No.                                                                   6889
# announce_date                                                     1/1/2021
# notification_date                                               12/31/2020
# sex                                                                   หญิง
# age                                                                     36
# nationality                                                       Cambodia
# province_of_isolation                                             ปทุมธานี
# province_of_onset                                            กรุงเทพมหานคร
# district_of_onset                                                   สายไหม
# risk                     อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# Name: 6888, dtype: object)
# (6889, No.                               6890
# announce_date                 1/1/2021
# notification_date           12/31/2020
# sex                                ชาย
# age                                 44
# nationality                   Thailand
# province_of_isolation    กรุงเทพมหานคร
# province_of_onset        กรุงเทพมหานคร
# district_of_onset                 สาธร
# risk                       สถานบันเทิง
# Name: 6889, dtype: object)
# (6890, No.                                          6891
# announce_date                            1/1/2021
# notification_date                      12/31/2020
# sex                                           ชาย
# age                                            60
# nationality                              Thailand
# province_of_isolation                    สุรินทร์
# province_of_onset                        สุรินทร์
# district_of_onset                   เมืองสุรินทร์
# risk                     Cluster บ่อนพัทยา/ชลบุรี
# Name: 6890, dtype: object)
# (6891, No.                                                                  6892
# announce_date                                                    1/1/2021
# notification_date                                              12/31/2020
# sex                                                                   ชาย
# age                                                                    39
# nationality                                                         Burma
# province_of_isolation                                             อ่างทอง
# province_of_onset                                                 อ่างทอง
# district_of_onset                                                   เมือง
# risk                     การค้นหาผู้ป่วยเชิงรุกและค้นหาผู้ติดเชื้อในชุมชน
# Name: 6891, dtype: object)
# (6892, No.                               6893
# announce_date                 1/1/2021
# notification_date           12/31/2020
# sex                                ชาย
# age                                 51
# nationality                   Thailand
# province_of_isolation    กรุงเทพมหานคร
# province_of_onset              ราชบุรี
# district_of_onset             บ้านโป่ง
# risk                       สถานบันเทิง
# Name: 6892, dtype: object)
# (6893, No.                               6894
# announce_date                 1/1/2021
# notification_date           12/31/2020
# sex                                ชาย
# age                                 59
# nationality                   Thailand
# province_of_isolation    กรุงเทพมหานคร
# province_of_onset        กรุงเทพมหานคร
# district_of_onset              บางพลัด
# risk                       สถานบันเทิง
# Name: 6893, dtype: object)
# (6894, No.                                                              6895
# announce_date                                                1/1/2021
# notification_date                                          12/31/2020
# sex                                                               ชาย
# age                                                                75
# nationality                                                  Thailand
# province_of_isolation                                   กรุงเทพมหานคร
# province_of_onset                                       กรุงเทพมหานคร
# district_of_onset                                              ประเวศ
# risk                     ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ
# Name: 6894, dtype: object)
# (6895, No.                                                                   6896
# announce_date                                                     1/1/2021
# notification_date                                               12/31/2020
# sex                                                                    ชาย
# age                                                                     30
# nationality                                                       Thailand
# province_of_isolation                                        กรุงเทพมหานคร
# province_of_onset                                            กรุงเทพมหานคร
# district_of_onset                                                 ดอนเมือง
# risk                     อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# Name: 6895, dtype: object)
# (6896, No.                               6897
# announce_date                 1/1/2021
# notification_date           12/31/2020
# sex                                ชาย
# age                                 32
# nationality                   Thailand
# province_of_isolation    กรุงเทพมหานคร
# province_of_onset              ชัยภูมิ
# district_of_onset             แก้งคร้อ
# risk                       สถานบันเทิง
# Name: 6896, dtype: object)
# (6897, No.                                                              6898
# announce_date                                                1/1/2021
# notification_date                                          12/31/2020
# sex                                                               ชาย
# age                                                                47
# nationality                                                  Slovenia
# province_of_isolation                                   กรุงเทพมหานคร
# province_of_onset                                       กรุงเทพมหานคร
# district_of_onset                                             จตุจักร
# risk                     ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ
# Name: 6897, dtype: object)
# (6898, No.                               6899
# announce_date                 1/1/2021
# notification_date           12/31/2020
# sex                               หญิง
# age                                 25
# nationality                   Thailand
# province_of_isolation    กรุงเทพมหานคร
# province_of_onset        กรุงเทพมหานคร
# district_of_onset               ธนบุรี
# risk                       สถานบันเทิง
# Name: 6898, dtype: object)
# (6899, No.                                                              6900
# announce_date                                                1/1/2021
# notification_date                                          12/31/2020
# sex                                                               ชาย
# age                                                                48
# nationality                                                     Italy
# province_of_isolation                                   กรุงเทพมหานคร
# province_of_onset                                       กรุงเทพมหานคร
# district_of_onset                                            ห้วยขวาง
# risk                     ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ
# Name: 6899, dtype: object)
# (6900, No.                               6901
# announce_date                 1/1/2021
# notification_date           12/31/2020
# sex                               หญิง
# age                                 38
# nationality                   Thailand
# province_of_isolation    กรุงเทพมหานคร
# province_of_onset        กรุงเทพมหานคร
# district_of_onset           บางกอกน้อย
# risk                       สถานบันเทิง
# Name: 6900, dtype: object)
# (6901, No.                                                              6902
# announce_date                                                1/1/2021
# notification_date                                          12/31/2020
# sex                                                               ชาย
# age                                                                46
# nationality                                                     China
# province_of_isolation                                   กรุงเทพมหานคร
# province_of_onset                                       กรุงเทพมหานคร
# district_of_onset                                                 NaN
# risk                     ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ
# Name: 6901, dtype: object)
# (6902, No.                               6903
# announce_date                 1/1/2021
# notification_date           12/31/2020
# sex                               หญิง
# age                                 53
# nationality                   Thailand
# province_of_isolation    กรุงเทพมหานคร
# province_of_onset        กรุงเทพมหานคร
# district_of_onset                พญาไท
# risk                       สถานบันเทิง
# Name: 6902, dtype: object)
# (6903, No.                               6904
# announce_date                 1/1/2021
# notification_date           12/31/2020
# sex                                ชาย
# age                                 61
# nationality                   Thailand
# province_of_isolation    กรุงเทพมหานคร
# province_of_onset        กรุงเทพมหานคร
# district_of_onset            ภาษีเจริญ
# risk                       สถานบันเทิง
# Name: 6903, dtype: object)
# (6904, No.                                                               6905
# announce_date                                                 1/1/2021
# notification_date                                           12/31/2020
# sex                                                                ชาย
# age                                                                 39
# nationality                                                   Thailand
# province_of_isolation                                      อุบลราชธานี
# province_of_onset                                              นนทบุรี
# district_of_onset                                            บางบัวทอง
# risk                     ไปสถานที่ชุมชน เช่น ตลาดนัด สถานที่ท่องเที่ยว
# Name: 6904, dtype: object)
# (6905, No.                                   6906
# announce_date                     1/1/2021
# notification_date               12/31/2020
# sex                                   หญิง
# age                                     33
# nationality                       Thailand
# province_of_isolation        กรุงเทพมหานคร
# province_of_onset                สมุทรสาคร
# district_of_onset                    เมือง
# risk                     Cluster สมุทรสาคร
# Name: 6905, dtype: object)
# (6906, No.                                                       6907
# announce_date                                         1/1/2021
# notification_date                                   12/31/2020
# sex                                                        ชาย
# age                                                         54
# nationality                                           Thailand
# province_of_isolation                            กรุงเทพมหานคร
# province_of_onset                                กรุงเทพมหานคร
# district_of_onset                                  ราษฎร์บูรณะ
# risk                     ไปสถานที่แออัด เช่น งานแฟร์ คอนเสิร์ต
# Name: 6906, dtype: object)
# (6907, No.                               6908
# announce_date                 1/1/2021
# notification_date           12/31/2020
# sex                               หญิง
# age                                 38
# nationality                    Vietnam
# province_of_isolation    กรุงเทพมหานคร
# province_of_onset        กรุงเทพมหานคร
# district_of_onset                วัฒนา
# risk                       สถานบันเทิง
# Name: 6907, dtype: object)
# (6908, No.                                                              6909
# announce_date                                                1/1/2021
# notification_date                                          12/31/2020
# sex                                                               ชาย
# age                                                                10
# nationality                                                     China
# province_of_isolation                                   กรุงเทพมหานคร
# province_of_onset                                       กรุงเทพมหานคร
# district_of_onset                                               วัฒนา
# risk                     ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ
# Name: 6908, dtype: object)
# (6909, No.                                   6910
# announce_date                     1/1/2021
# notification_date               12/31/2020
# sex                                   หญิง
# age                                     49
# nationality                       Thailand
# province_of_isolation        นครศรีธรรมราช
# province_of_onset            นครศรีธรรมราช
# district_of_onset                    เมือง
# risk                     Cluster สมุทรสาคร
# Name: 6909, dtype: object)
# (6910, No.                               6911
# announce_date                 1/1/2021
# notification_date           12/31/2020
# sex                                ชาย
# age                                 60
# nationality                   Thailand
# province_of_isolation    กรุงเทพมหานคร
# province_of_onset        กรุงเทพมหานคร
# district_of_onset              ปทุมวัน
# risk                     Cluster ระยอง
# Name: 6910, dtype: object)
# (6911, No.                                                             6912
# announce_date                                               1/1/2021
# notification_date                                         12/31/2020
# sex                                                             หญิง
# age                                                               40
# nationality                                                 Thailand
# province_of_isolation                                  กรุงเทพมหานคร
# province_of_onset                                      กรุงเทพมหานคร
# district_of_onset                                            หนองจอก
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 6911, dtype: object)
# (6912, No.                                                             6913
# announce_date                                               1/1/2021
# notification_date                                         12/31/2020
# sex                                                             หญิง
# age                                                               52
# nationality                                                 Thailand
# province_of_isolation                                  กรุงเทพมหานคร
# province_of_onset                                      กรุงเทพมหานคร
# district_of_onset                                             บางรัก
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 6912, dtype: object)
# (6913, No.                                                             6914
# announce_date                                               1/1/2021
# notification_date                                         12/31/2020
# sex                                                             หญิง
# age                                                               61
# nationality                                                 Thailand
# province_of_isolation                                  กรุงเทพมหานคร
# province_of_onset                                      กรุงเทพมหานคร
# district_of_onset                                              วัฒนา
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 6913, dtype: object)
# (6914, No.                                                             6915
# announce_date                                               1/1/2021
# notification_date                                         12/31/2020
# sex                                                             หญิง
# age                                                               37
# nationality                                                 Thailand
# province_of_isolation                                  กรุงเทพมหานคร
# province_of_onset                                      กรุงเทพมหานคร
# district_of_onset                                         วังทองหลาง
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 6914, dtype: object)
# (6915, No.                                                             6916
# announce_date                                               1/1/2021
# notification_date                                         12/31/2020
# sex                                                             หญิง
# age                                                               25
# nationality                                                 Thailand
# province_of_isolation                                  กรุงเทพมหานคร
# province_of_onset                                      กรุงเทพมหานคร
# district_of_onset                                              วัฒนา
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 6915, dtype: object)
# (6916, No.                                                              6917
# announce_date                                                1/1/2021
# notification_date                                          12/31/2020
# sex                                                               ชาย
# age                                                                58
# nationality                                                   Germany
# province_of_isolation                                   กรุงเทพมหานคร
# province_of_onset                                       กรุงเทพมหานคร
# district_of_onset                                               วัฒนา
# risk                     ผู้ที่เดินทางมาจากต่างประเทศ และเข้า ASQ/ALQ
# Name: 6916, dtype: object)
# (6917, No.                                                             6918
# announce_date                                               1/1/2021
# notification_date                                         12/31/2020
# sex                                                             หญิง
# age                                                               42
# nationality                                                 Thailand
# province_of_isolation                                  กรุงเทพมหานคร
# province_of_onset                                      กรุงเทพมหานคร
# district_of_onset                                             จอมทอง
# risk                     สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# Name: 6917, dtype: object)
# (6918, No.                               6919
# announce_date                 1/1/2021
# notification_date           12/31/2020
# sex                               หญิง
# age                                 29
# nationality                   Thailand
# province_of_isolation            ลำพูน
# province_of_onset                ลำพูน
# district_of_onset                  ลี้
# risk                     Cluster ระยอง
# Name: 6918, dtype: object)
# (6919, No.                                      6920
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                        34
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6919, dtype: object)
# (6920, No.                                      6921
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        75
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6920, dtype: object)
# (6921, No.                                      6922
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        39
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6921, dtype: object)
# (6922, No.                                      6923
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                        58
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6922, dtype: object)
# (6923, No.                                      6924
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                        51
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6923, dtype: object)
# (6924, No.                                      6925
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                        30
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6924, dtype: object)
# (6925, No.                                      6926
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        35
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6925, dtype: object)
# (6926, No.                                      6927
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                        55
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6926, dtype: object)
# (6927, No.                                      6928
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        34
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6927, dtype: object)
# (6928, No.                                      6929
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        29
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6928, dtype: object)
# (6929, No.                                      6930
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        36
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6929, dtype: object)
# (6930, No.                                      6931
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        42
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6930, dtype: object)
# (6931, No.                                      6932
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        33
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6931, dtype: object)
# (6932, No.                                      6933
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                        56
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6932, dtype: object)
# (6933, No.                                      6934
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        36
# nationality                             Burma
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6933, dtype: object)
# (6934, No.                                      6935
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        40
# nationality                             Burma
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6934, dtype: object)
# (6935, No.                                      6936
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        20
# nationality                             Burma
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6935, dtype: object)
# (6936, No.                                      6937
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        30
# nationality                             Burma
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6936, dtype: object)
# (6937, No.                                      6938
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        40
# nationality                             Burma
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6937, dtype: object)
# (6938, No.                                      6939
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        24
# nationality                             Burma
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6938, dtype: object)
# (6939, No.                                      6940
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                        60
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6939, dtype: object)
# (6940, No.                                      6941
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        64
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6940, dtype: object)
# (6941, No.                                      6942
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                        23
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6941, dtype: object)
# (6942, No.                                      6943
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                        26
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6942, dtype: object)
# (6943, No.                                      6944
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                        53
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6943, dtype: object)
# (6944, No.                                      6945
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        19
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6944, dtype: object)
# (6945, No.                                      6946
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                        20
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6945, dtype: object)
# (6946, No.                                      6947
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        51
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6946, dtype: object)
# (6947, No.                                      6948
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                        14
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6947, dtype: object)
# (6948, No.                                      6949
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                        59
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6948, dtype: object)
# (6949, No.                                      6950
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                        36
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6949, dtype: object)
# (6950, No.                                      6951
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                        45
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6950, dtype: object)
# (6951, No.                                      6952
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                        51
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6951, dtype: object)
# (6952, No.                                      6953
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                        53
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6952, dtype: object)
# (6953, No.                                      6954
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                        54
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6953, dtype: object)
# (6954, No.                                      6955
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                        45
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6954, dtype: object)
# (6955, No.                                      6956
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                        21
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6955, dtype: object)
# (6956, No.                                      6957
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                        70
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6956, dtype: object)
# (6957, No.                                      6958
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        70
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6957, dtype: object)
# (6958, No.                                      6959
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        56
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6958, dtype: object)
# (6959, No.                                      6960
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        40
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6959, dtype: object)
# (6960, No.                                      6961
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        12
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6960, dtype: object)
# (6961, No.                                      6962
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        43
# nationality                             Burma
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6961, dtype: object)
# (6962, No.                                      6963
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        47
# nationality                             Burma
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6962, dtype: object)
# (6963, No.                                      6964
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        28
# nationality                             Burma
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6963, dtype: object)
# (6964, No.                                      6965
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                        22
# nationality                             Burma
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6964, dtype: object)
# (6965, No.                                      6966
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        41
# nationality                             Burma
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6965, dtype: object)
# (6966, No.                                      6967
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        26
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6966, dtype: object)
# (6967, No.                                      6968
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        35
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6967, dtype: object)
# (6968, No.                                      6969
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        28
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6968, dtype: object)
# (6969, No.                                      6970
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        64
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6969, dtype: object)
# (6970, No.                                      6971
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        48
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6970, dtype: object)
# (6971, No.                                      6972
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        18
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6971, dtype: object)
# (6972, No.                                      6973
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        14
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6972, dtype: object)
# (6973, No.                                      6974
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        11
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 6973, dtype: object)
# (6974, No.                                      6975
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                        33
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# ...
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7130, dtype: object)
# (7131, No.                                      7132
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       NaN
# age                                       NaN
# nationality                          Cambodia
# province_of_isolation                จันทบุรี
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7131, dtype: object)
# (7132, No.                                      7133
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       NaN
# age                                       NaN
# nationality                          Cambodia
# province_of_isolation                จันทบุรี
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7132, dtype: object)
# (7133, No.                                      7134
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       NaN
# age                                       NaN
# nationality                          Cambodia
# province_of_isolation                จันทบุรี
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7133, dtype: object)
# (7134, No.                                      7135
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       NaN
# age                                       NaN
# nationality                          Cambodia
# province_of_isolation                จันทบุรี
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7134, dtype: object)
# (7135, No.                                      7136
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       NaN
# age                                       NaN
# nationality                          Cambodia
# province_of_isolation                จันทบุรี
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7135, dtype: object)
# (7136, No.                                      7137
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       NaN
# age                                       NaN
# nationality                          Cambodia
# province_of_isolation                จันทบุรี
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7136, dtype: object)
# (7137, No.                                      7138
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       NaN
# age                                       NaN
# nationality                          Cambodia
# province_of_isolation                จันทบุรี
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7137, dtype: object)
# (7138, No.                                      7139
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       NaN
# age                                       NaN
# nationality                          Cambodia
# province_of_isolation                จันทบุรี
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7138, dtype: object)
# (7139, No.                                      7140
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       NaN
# age                                       NaN
# nationality                          Cambodia
# province_of_isolation                จันทบุรี
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7139, dtype: object)
# (7140, No.                                      7141
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       NaN
# age                                       NaN
# nationality                          Cambodia
# province_of_isolation             สมุทรปราการ
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7140, dtype: object)
# (7141, No.                                      7142
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       NaN
# age                                       NaN
# nationality                          Cambodia
# province_of_isolation             สมุทรปราการ
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7141, dtype: object)
# (7142, No.                                      7143
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                       NaN
# nationality                          Thailand
# province_of_isolation             สมุทรปราการ
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7142, dtype: object)
# (7143, No.                                      7144
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                       NaN
# nationality                          Thailand
# province_of_isolation             สมุทรปราการ
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7143, dtype: object)
# (7144, No.                                      7145
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                       NaN
# nationality                          Thailand
# province_of_isolation             สมุทรปราการ
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7144, dtype: object)
# (7145, No.                                      7146
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       NaN
# age                                       NaN
# nationality                          Thailand
# province_of_isolation             สมุทรปราการ
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7145, dtype: object)
# (7146, No.                                      7147
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                        55
# nationality                          Thailand
# province_of_isolation               สมุทรสาคร
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7146, dtype: object)
# (7147, No.                                      7148
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                       NaN
# nationality                          Thailand
# province_of_isolation             สมุทรปราการ
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7147, dtype: object)
# (7148, No.                                      7149
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                       NaN
# nationality                          Thailand
# province_of_isolation             สมุทรปราการ
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7148, dtype: object)
# (7149, No.                                      7150
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                       NaN
# nationality                          Thailand
# province_of_isolation             สมุทรปราการ
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7149, dtype: object)
# (7150, No.                                      7151
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                       NaN
# nationality                          Thailand
# province_of_isolation             สมุทรปราการ
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7150, dtype: object)
# (7151, No.                                      7152
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                       NaN
# nationality                          Thailand
# province_of_isolation             สมุทรปราการ
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7151, dtype: object)
# (7152, No.                                      7153
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                       NaN
# nationality                          Thailand
# province_of_isolation             สมุทรปราการ
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7152, dtype: object)
# (7153, No.                                      7154
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                       NaN
# nationality                          Thailand
# province_of_isolation                    ตราด
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7153, dtype: object)
# (7154, No.                                      7155
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                       NaN
# nationality                          Thailand
# province_of_isolation                    ตราด
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7154, dtype: object)
# (7155, No.                                      7156
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                       NaN
# nationality                          Thailand
# province_of_isolation                    ตราด
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7155, dtype: object)
# (7156, No.                                      7157
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                       NaN
# nationality                          Thailand
# province_of_isolation                    ตราด
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7156, dtype: object)
# (7157, No.                                      7158
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       NaN
# age                                       NaN
# nationality                          Cambodia
# province_of_isolation                    ตราด
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7157, dtype: object)
# (7158, No.                                      7159
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       NaN
# age                                       NaN
# nationality                          Cambodia
# province_of_isolation                    ตราด
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7158, dtype: object)
# (7159, No.                                      7160
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       NaN
# age                                       NaN
# nationality                          Cambodia
# province_of_isolation                    ตราด
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7159, dtype: object)
# (7160, No.                                      7161
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                       NaN
# nationality                          Thailand
# province_of_isolation                 สระแก้ว
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7160, dtype: object)
# (7161, No.                                      7162
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                       ชาย
# age                                       NaN
# nationality                          Thailand
# province_of_isolation                 สระแก้ว
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7161, dtype: object)
# (7162, No.                                      7163
# announce_date                        1/1/2021
# notification_date                  12/31/2020
# sex                                      หญิง
# age                                       NaN
# nationality                          Thailand
# province_of_isolation              ฉะเชิงเทรา
# province_of_onset                         NaN
# district_of_onset                         NaN
# risk                     อยู่ระหว่างการสอบสวน
# Name: 7162, dtype: object)

# %%
data_2021 = data_covid[6884::]
data_2021
# Out:
#          No.  ...                                               risk
# 6884    6885  ...                                  Cluster สมุทรสาคร
# 6885    6886  ...                                      Cluster ระยอง
# 6886    6887  ...                                        สถานบันเทิง
# 6887    6888  ...                                  Cluster สมุทรสาคร
# 6888    6889  ...  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
# ...      ...  ...                                                ...
# 12648  12649  ...                                   State Quarantine
# 12649  12650  ...        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12650  12651  ...        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
# 12651  12652  ...                                      Cluster ระยอง
# 12652  12653  ...        สัมผัสใกล้ชิดกับผู้ป่วยยืนยันรายก่อนหน้านี้
#
# [5769 rows x 10 columns]

# %% [markdown]
# ###เฉลย QUIZ

# %%
TF = list()
for each_row in data_covid.iterrows():
      print(each_row[1]['announce_date'].split('/'))
      if each_row[1]['announce_date'].split('/')[2] == '2021':
          TF.append(True) #เอาเเถวนี้
      else:
          TF.append(False) #ไม่เอาเเถวนี้
data_covid[TF].head()
# Out:
# Streaming output truncated to the last 5000 lines.
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '3', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '4', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '5', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '6', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '7', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '8', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '9', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ['1', '10', '2021']
# ...
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '17', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '18', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '19', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
# ['1', '20', '2021']
#        No.  ...                                               risk
# 6884  6885  ...                                  Cluster สมุทรสาคร
# 6885  6886  ...                                      Cluster ระยอง
# 6886  6887  ...                                        สถานบันเทิง
# 6887  6888  ...                                  Cluster สมุทรสาคร
# 6888  6889  ...  อาชีพเสี่ยง เช่น ทำงานในสถานที่แออัด หรือทำงาน...
#
# [5 rows x 10 columns]

# %%
TF
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  ...]

# %% [markdown]
# ###Function ตัวช่วยใน pandas

# %%
data_covid.describe() #คำนวณค่าสถิติของข้อมูลที่เป็นตัวเลข
# Out:
#                 No.          age
# count  12653.000000  8881.000000
# mean    6327.000000    38.054748
# std     3652.750813    15.125178
# min        1.000000     0.100000
# 25%     3164.000000    27.000000
# 50%     6327.000000    36.000000
# 75%     9490.000000    48.000000
# max    12653.000000    97.000000

# %%
data_covid[data_covid['sex']=='ชาย']['age'].mean() #คำนวณค่าเฉลี่ยของข้อมูลโดยไม่สนใจ missing
# Out:
# 39.46076940331987

# %% [markdown]
# ###```isnull```

# %%
data_covid.isnull()
# Out:
#          No.  announce_date  ...  district_of_onset   risk
# 0      False          False  ...               True  False
# 1      False          False  ...               True  False
# 2      False          False  ...              False  False
# 3      False          False  ...               True  False
# 4      False          False  ...               True  False
# ...      ...            ...  ...                ...    ...
# 12648  False          False  ...              False  False
# 12649  False          False  ...              False  False
# 12650  False          False  ...              False  False
# 12651  False          False  ...              False  False
# 12652  False          False  ...              False  False
#
# [12653 rows x 10 columns]
